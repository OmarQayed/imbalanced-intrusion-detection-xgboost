# %% [markdown]
# # 01 — Exploratory Data Analysis

# %% [markdown]
# This notebook is reserved for exploratory analysis of the corrected CICIDS2017 dataset. Planned work includes:
#
# - loading the corrected CICIDS2017 dataset;
# - inspecting class distributions;
# - checking missing, infinite and duplicate values;
# - identifying minority attack classes;
# - exploratory visualisations.

# %% [markdown]
# Status: Planned — experimental implementation has not yet been performed.
