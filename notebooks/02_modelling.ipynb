# %% [markdown]
# # 02 — Modelling

# %% [markdown]
# This notebook is reserved for the proposed XGBoost experimental comparison on the corrected CICIDS2017 dataset. Planned work includes:
#
# - unweighted XGBoost;
# - cost-sensitive XGBoost;
# - training-only SMOTE-XGBoost;
# - evaluation using Macro-F1, per-class precision, recall and F1, false-positive rate and confusion matrices;
# - repeated evaluation across random seeds where feasible.

# %% [markdown]
# Status: Planned — experimental implementation has not yet been performed.
